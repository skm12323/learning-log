# %% [markdown]
#  - ex 1

# %%
h = 6.62607015e-34
c = 2.99792458e8
wl = 500.e-9
E = h * c / wl
print(f"光子能量 E = {E:.4e}")
# Out:
# 光子能量 E = 3.973e-19

# %% [markdown]
#  - ex 2

# %%
print(0.1 + 0.2 == 0.3)
print(abs(0.1 + 0.2 - 0.3) <= 1e-12)
# Out:
# False
# True

# %% [markdown]
#  - ex 3

# %%
print(2 ** 100)
print(2.0 ** 100)
a = 2.0 ** 100
print(a * 2 == 2 ** 101)
print(a * 2 ** 2 == 2 ** 102)
print(a * 2 ** 3 == 2 ** 103)
print(a * 2 ** 4 == 2 ** 104)
print(a * 2 ** 5 == 2 ** 105)
print(a * 2 ** 6 == 2 ** 106)
print(a * 2 ** 7 == 2 ** 107)
print(a * 2 ** 8 == 2 ** 108)
print(a * 2 ** 9 == 2 ** 109)
print(a * 2 ** 10 == 2 ** 110)
# Out:
# 1267650600228229401496703205376
# 1.2676506002282294e+30
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
#  - ex 4

# %%
s = "superconductivity"
s = s[0:5][::-1] + s[5:]
print(s)
s = s[::-1]
print(s)
s.count('u')
# Out:
# repusconductivity
# ytivitcudnocsuper
# 2

# %% [markdown]
#  - ex 5

# %%
s = "2.99792458,6.62607015,1.602176634"
ls = s.split(',')
ls[1] = float(ls[1])
print(ls[1], type(ls[1]))
# Out:
# 6.62607015 <class 'float'>

# %% [markdown]
#  - ex 6

# %%
primes = [2,3,5,7,11,13,17]
primes.append(19)
primes.remove(7)
primes.sort(reverse = True)
print(primes, sum(primes), min(primes))
# Out:
# [19, 17, 13, 11, 5, 3, 2] 70 2

# %% [markdown]
#  - ex 7

# %%
a = [1, 2]
b = a
b += [3]
print(a, b, a is b)
# Out:
# [1, 2, 3] [1, 2, 3] True

# %%
a = [1, 2]
c = a.copy()
c.append(9)
print(a, c, a is c)
# Out:
# [1, 2] [1, 2, 9] False

# %% [markdown]
#  - ex 8

# %%
p = (3, 4, 5)
px, py, pz = p
px, pz = pz, px
print((px * px + py * py + pz * pz) ** 0.5)
# Out:
# 7.0710678118654755
